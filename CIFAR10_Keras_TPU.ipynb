# %% [markdown]
# # CIFAR 10 Classification: TPU Version
#
# The goal of this notebook is to implement a simple conv net to classify CIFAR10 images using TPU and compare its training time against GPU on local workstation and Colab GPU.

# %%
import os
from time import time
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf

# %%
# check tensorflow version, we want the one that support eager mode
tf.__version__
# Out:
# '1.11.0'

# %%
# Turn on the eager mode
#tf.enable_eager_execution()

# %%
# Check if eager execution mode is on
tf.executing_eagerly()
# Out:
# False

# %% [markdown]
# # Dataset
#
# Load CIFAR10 dataset

# %%
from tensorflow.keras.datasets import cifar10, mnist

(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()
print('x_train_full shape: {}, y_train_full.shape: {}'
      .format(x_train_full.shape, y_train_full.shape))
print('x_test shape: {}, y_test.shape: {}'.format(x_test.shape, y_test.shape))
# Out:
# x_train_full shape: (50000, 32, 32, 3), y_train_full.shape: (50000, 1)
# x_test shape: (10000, 32, 32, 3), y_test.shape: (10000, 1)

# %%
y_train_full = y_train_full.reshape(y_train_full.shape[0],)
y_test = y_test.reshape(y_test.shape[0],)
print('y_train_full shape: {}, y_test shape: {}'
      .format(y_train_full.shape, y_test.shape))
# Out:
# y_train_full shape: (50000,), y_test shape: (10000,)

# %%
# create validation set
split = 0.2
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full, test_size=0.2, random_state=42)
print('x_train: {}, y_train: {}, x_val: {}, y_val: {}'
      .format(x_train.shape, y_train.shape, x_val.shape, y_val.shape))
# Out:
# x_train: (40000, 32, 32, 3), y_train: (40000,), x_val: (10000, 32, 32, 3), y_val: (10000,)

# %% [markdown]
# Lets plot 25 random images to get some idea about the dataset

# %%
# pick 25 random images and plot
idxs = np.random.randint(x_train.shape[0], size=25)
images = x_train[idxs]
labels = y_train[idxs]
classnames = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
fig, axes = plt.subplots(5,5, figsize=(8,9))
for i, ax in enumerate(axes.flat):
  ax.imshow(images[i])
  ax.axis('off')
  idx = labels[i]
  ax.set_title(classnames[idx])

plt.show()

# %%
# Using Dataset
# def scale(x, min_val=0.0, max_val=255.0):
#   x = tf.to_float(x)
#   return tf.div(tf.subtract(x, min_val), tf.subtract(max_val, min_val))

# convert to dataset
# train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
# train_ds = train_ds.map(lambda x, y: (scale(x), tf.one_hot(y, 10))).shuffle(10000)

# test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))
# test_ds = test_ds.map(lambda x, y: (scale(x), tf.one_hot(y, 10))).shuffle(10000)

# def train_generator(batch_size):
#   while True:
#     images, labels = train_ds.batch(batch_size).make_one_shot_iterator().get_next()
#     yield images, labels

# %%
def train_gen(batch_size):
  while True:
    offset = np.random.randint(0, x_train.shape[0] - batch_size)
    yield x_train[offset:offset+batch_size], y_train[offset:offset + batch_size]

# %% [markdown]
# # Build a model

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(32, (3,3), padding='same', activation='relu', input_shape=(32,32,3)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3)))
model.add(tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3)))
model.add(tf.keras.layers.Conv2D(128, (3,3), padding='same', activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.4))
model.add(tf.keras.layers.Dense(10, activation='relu'))
model.add(tf.keras.layers.Activation('softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 10, 10, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# _________________________________________________________________
# activation (Activation)      (None, 10)                0
# =================================================================
# Total params: 111,946
# Trainable params: 111,498
# Non-trainable params: 448
# _________________________________________________________________

# %%
tpu_model = tf.contrib.tpu.keras_to_tpu_model(
    model,
    strategy=tf.contrib.tpu.TPUDistributionStrategy(
        tf.contrib.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])
    )
)
# Out:
# INFO:tensorflow:Querying Tensorflow master (b'grpc://10.4.66.154:8470') for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, -1, 11020924145696970991)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 8642668331513702465)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_GPU:0, XLA_GPU, 17179869184, 8299197535424466515)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 6609252292601826176)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 4156117743592455349)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 7482691375750755915)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 11234191712606254118)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 7932058859831483765)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 11938862595229068735)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 10332782459826376580)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 2216244176311607036)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 17179869184, 1431070260623692239)
# WARNING:tensorflow:tpu_model (from tensorflow.contrib.tpu.python.tpu.keras_support) is experimental and may change or be removed at any time, and without warning.
# INFO:tensorflow:Connecting to: b'grpc://10.4.66.154:8470'

# %% [markdown]
# # Train
#
# Train the model on TPU

# %%
tpu_model.compile(
    optimizer=tf.train.AdamOptimizer(learning_rate=1e-3, ),
    loss=tf.keras.losses.sparse_categorical_crossentropy,
    metrics=['sparse_categorical_accuracy']
)

# %%
batch_size=1024
start = time()
history = tpu_model.fit_generator(
    train_gen(batch_size), epochs=25, 
    steps_per_epoch=np.ceil(x_train.shape[0]/batch_size),
    validation_data = (x_val, y_val),
)
end = time()
# Out:
# Epoch 1/25
# INFO:tensorflow:New input shapes; (re-)compiling: mode=train, [TensorSpec(shape=(128, 32, 32, 3), dtype=tf.float32, name='conv2d_input0'), TensorSpec(shape=(128, 1), dtype=tf.float32, name='activation_target0')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for conv2d_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 2.1916587352752686 secs
# INFO:tensorflow:Setting weights on TPU model.
# 39/40 [============================>.] - ETA: 0s - loss: 2.2491 - sparse_categorical_accuracy: 0.2121INFO:tensorflow:New input shapes; (re-)compiling: mode=eval, [TensorSpec(shape=(128, 32, 32, 3), dtype=tf.float32, name='conv2d_input0'), TensorSpec(shape=(128, 1), dtype=tf.float32, name='activation_target0')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for conv2d_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 0.7664756774902344 secs
# INFO:tensorflow:New input shapes; (re-)compiling: mode=eval, [TensorSpec(shape=(98, 32, 32, 3), dtype=tf.float32, name='conv2d_input0'), TensorSpec(shape=(98, 1), dtype=tf.float32, name='activation_target0')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for conv2d_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 0.7810955047607422 secs
# 40/40 [==============================] - 13s 317ms/step - loss: 2.2433 - sparse_categorical_accuracy: 0.2131 - val_loss: 2.3941 - val_sparse_categorical_accuracy: 0.1088
# Epoch 2/25
# 40/40 [==============================] - 5s 131ms/step - loss: 1.7886 - sparse_categorical_accuracy: 0.3670 - val_loss: 1.9813 - val_sparse_categorical_accuracy: 0.2872
# Epoch 3/25
# 40/40 [==============================] - 5s 129ms/step - loss: 1.4540 - sparse_categorical_accuracy: 0.4912 - val_loss: 1.7661 - val_sparse_categorical_accuracy: 0.3440
# Epoch 4/25
# 40/40 [==============================] - 5s 128ms/step - loss: 1.2071 - sparse_categorical_accuracy: 0.5863 - val_loss: 1.3052 - val_sparse_categorical_accuracy: 0.5576
# Epoch 5/25
# 40/40 [==============================] - 5s 131ms/step - loss: 1.0940 - sparse_categorical_accuracy: 0.6187 - val_loss: 1.1821 - val_sparse_categorical_accuracy: 0.5952
# Epoch 6/25
# 40/40 [==============================] - 5s 131ms/step - loss: 0.9763 - sparse_categorical_accuracy: 0.6670 - val_loss: 1.2996 - val_sparse_categorical_accuracy: 0.5360
# Epoch 7/25
# 40/40 [==============================] - 5s 127ms/step - loss: 0.8964 - sparse_categorical_accuracy: 0.6877 - val_loss: 1.0116 - val_sparse_categorical_accuracy: 0.6560
# Epoch 8/25
# 40/40 [==============================] - 5s 130ms/step - loss: 0.8752 - sparse_categorical_accuracy: 0.6949 - val_loss: 1.0909 - val_sparse_categorical_accuracy: 0.6200
# Epoch 9/25
# 40/40 [==============================] - 5s 128ms/step - loss: 0.8316 - sparse_categorical_accuracy: 0.7139 - val_loss: 1.1383 - val_sparse_categorical_accuracy: 0.6048
# Epoch 10/25
# 40/40 [==============================] - 5s 129ms/step - loss: 0.7814 - sparse_categorical_accuracy: 0.7359 - val_loss: 0.9591 - val_sparse_categorical_accuracy: 0.6688
# Epoch 11/25
# 40/40 [==============================] - 5s 130ms/step - loss: 0.7255 - sparse_categorical_accuracy: 0.7496 - val_loss: 0.9119 - val_sparse_categorical_accuracy: 0.6784
# Epoch 12/25
# 40/40 [==============================] - 5s 131ms/step - loss: 0.6232 - sparse_categorical_accuracy: 0.7820 - val_loss: 0.9539 - val_sparse_categorical_accuracy: 0.6808
# Epoch 13/25
# 40/40 [==============================] - 5s 127ms/step - loss: 0.6564 - sparse_categorical_accuracy: 0.7686 - val_loss: 0.9520 - val_sparse_categorical_accuracy: 0.6864
# Epoch 14/25
# 40/40 [==============================] - 5s 130ms/step - loss: 0.6031 - sparse_categorical_accuracy: 0.7980 - val_loss: 1.0069 - val_sparse_categorical_accuracy: 0.6848
# Epoch 15/25
# 40/40 [==============================] - 5s 127ms/step - loss: 0.5322 - sparse_categorical_accuracy: 0.8137 - val_loss: 1.0221 - val_sparse_categorical_accuracy: 0.6736
# Epoch 16/25
# 40/40 [==============================] - 5s 126ms/step - loss: 0.5302 - sparse_categorical_accuracy: 0.8209 - val_loss: 0.9784 - val_sparse_categorical_accuracy: 0.6944
# Epoch 17/25
# 40/40 [==============================] - 5s 131ms/step - loss: 0.5004 - sparse_categorical_accuracy: 0.8281 - val_loss: 0.9404 - val_sparse_categorical_accuracy: 0.6928
# Epoch 18/25
# 40/40 [==============================] - 5s 130ms/step - loss: 0.4720 - sparse_categorical_accuracy: 0.8432 - val_loss: 1.0354 - val_sparse_categorical_accuracy: 0.6880
# Epoch 19/25
# 40/40 [==============================] - 5s 125ms/step - loss: 0.4894 - sparse_categorical_accuracy: 0.8352 - val_loss: 0.9765 - val_sparse_categorical_accuracy: 0.7048
# Epoch 20/25
# 40/40 [==============================] - 5s 126ms/step - loss: 0.4484 - sparse_categorical_accuracy: 0.8492 - val_loss: 1.1232 - val_sparse_categorical_accuracy: 0.6840
# Epoch 21/25
# 40/40 [==============================] - 5s 126ms/step - loss: 0.3846 - sparse_categorical_accuracy: 0.8678 - val_loss: 1.0180 - val_sparse_categorical_accuracy: 0.7064
# Epoch 22/25
# 40/40 [==============================] - 5s 125ms/step - loss: 0.3338 - sparse_categorical_accuracy: 0.8799 - val_loss: 1.1377 - val_sparse_categorical_accuracy: 0.6872
# Epoch 23/25
# 40/40 [==============================] - 5s 125ms/step - loss: 0.3504 - sparse_categorical_accuracy: 0.8783 - val_loss: 1.0766 - val_sparse_categorical_accuracy: 0.6992
# Epoch 24/25
# 40/40 [==============================] - 5s 130ms/step - loss: 0.3580 - sparse_categorical_accuracy: 0.8748 - val_loss: 1.0591 - val_sparse_categorical_accuracy: 0.7016
# Epoch 25/25
# 40/40 [==============================] - 5s 129ms/step - loss: 0.3563 - sparse_categorical_accuracy: 0.8732 - val_loss: 1.1082 - val_sparse_categorical_accuracy: 0.7064

# %%
print('Total training time {} seconds'.format(end - start))
# Out:
# Total training time 136.04949831962585 seconds

# %%
def plot(losses, accuracies, subplot_title):
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14,4))
  
  ax1.plot(losses)
  ax1.set_xlabel('Epochs')
  ax1.set_ylabel('Loss')
  ax1.set_title(subplot_title[0])
  
  ax2.plot(accuracies)
  ax2.set_xlabel('Epochs')
  ax2.set_ylabel('Accuracy')
  ax2.set_title(subplot_title[1])
    
  plt.show()

# %% [markdown]
# ### Plot Loss and Accuracy
#
# Lets see how did we do on training and validation sets

# %%
# Training
plot(history.history['loss'], 
     history.history['sparse_categorical_accuracy'], 
     subplot_title=['Training Loss', 'Training Accuracy']
    )

# %%
# Validation
plot(history.history['val_loss'], 
     history.history['val_sparse_categorical_accuracy'], 
     subplot_title=['Validation Loss', 'Validation Accuracy']
    )

# %% [markdown]
# # Test accuracy
#
# Next, we plot the model predictions on test set

# %%
cpu_model = tpu_model.sync_to_cpu()
# Out:
# INFO:tensorflow:Copying TPU weights to the CPU

# %%
idxs = np.random.randint(x_test.shape[0], size=25)
images = x_test[idxs]
true_labels = y_test[idxs]

preds = np.argmax(cpu_model.predict(images), axis=1)

# %%
fig, axes = plt.subplots(5,5, figsize=(8,9))
for i, ax in enumerate(axes.flat):
  ax.imshow(images[i])
  ax.axis('off')
  idx = preds[i]
  color = 'g' if idx == true_labels[i] else 'r'
  ax.set_title(classnames[idx], color=color)

plt.show()

# %% [markdown]
# Now that we've got the basic model working, you can try improving its accuracy.
# For example, you can try :
# * preprocessing
# * transfer learning
# * learning rates using learning rate finder
# * different network architecture
#
#
# You can try to match/beat the CIFAR10 accuracy listed on this <a href="http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130">page</a>.
